# %% [markdown]
# <a href="https://colab.research.google.com/github/Wilanth/Python_dataviz2023/blob/main/Tast%20code%20before%20final%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Read  Excel file
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx')
region = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'region')
result_constituencies_PartyList = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'result_constituencies_PartyList')
result_constituencies_Candidate = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'result_constituencies_Candidate')
result_constituencies_status = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'result_constituencies_status')
info_province = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'info_province')
info_party_overview = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'info_party_overview')
info_constituency = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'info_constituency')
Candidate_Constituency = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'Candidate_Constituency')
Candidate_PartyList = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'Candidate_PartyList')
Candidate_PM = pd.read_excel('/content/drive/MyDrive/Dataviz23Data/ectreport2023_มีภาค.xlsx', sheet_name = 'Candidate_PM')

# %%
region
# Out:
#   region_id            region_name
# 0       R01               ภาคเหนือ
# 1       R02  ภาคตะวันออกเฉียงเหนือ
# 2       R03                ภาคกลาง
# 3       R04                 ภาคใต้
# 4       R05             ภาคตะวันตก
# 5       R06            ภาคตะวันออก

# %%
#Read csv file
import csv

# %%
df1 =  pd.read_csv('/content/drive/MyDrive/Dataviz23Data/creditcard_2023.csv',header=4,index_col=0) #

# %%
df1
# Out:
#         -0.15215210191356718  -0.508958707673651  1.746840058804548  \
# 3
# 4                  -0.206820           -0.165280           1.527053
# 5                   0.025302           -0.140514           1.191138
# 6                   1.016482           -0.397181           0.497868
# 7                  -0.051306           -0.007194           1.139941
# 8                  -0.130680           -0.349547           0.425786
# ...                      ...                 ...                ...
# 568625             -0.833437            0.061886          -0.899794
# 568626             -0.670459           -0.202896          -0.068129
# 568627             -0.311997           -0.004095           0.137526
# 568628              0.636871           -0.516970          -0.300889
# 568629             -0.795144            0.433236          -0.649140
#
#         -1.090177941714601  0.2494857726542817  1.1433122633143087  \
# 3
# 4                -0.448293            0.106125            0.530549
# ...

# %%
df1.describe()
# Out:
#        -0.15215210191356718  -0.508958707673651  1.746840058804548  \
# count          5.686260e+05       568626.000000      568626.000000
# mean          -5.487407e-07            0.000004          -0.000011
# std            1.000003e+00            1.000003           0.999993
# min           -3.495584e+00          -49.966572          -3.183760
# 25%           -5.652958e-01           -0.486670          -0.649307
# 50%           -9.363458e-02           -0.135893           0.000348
# 75%            8.326582e-01            0.343556           0.628534
# max            2.229046e+00            4.361865          14.125834
#
#        -1.090177941714601  0.2494857726542817  1.1433122633143087  \
# count       568626.000000       568626.000000       568626.000000
# mean             0.000004           -0.000001           -0.000007
# std              1.000003            1.000004            1.000001
# min             -4.951222           -9.952786          -21.111108
# ...

# %% [markdown]
# # วิธีการดูค่า null
#
#
# 1.   เลือกคอลัมน์ที่ต้องการดูค่า Null ในแต่ละชีท

# %%
result_constituencies_Candidate.describe()
# Out:
#        mp_app_rank   mp_app_vote  mp_app_vote_percent     party_id
# count  4781.000000   4781.000000          4781.000000  4781.000000
# mean      6.711985   7654.289898             8.223124   733.349090
# std       3.845837  12389.868008            19.185614    23.968199
# min       1.000000      0.000000             0.000000   701.000000
# 25%       3.000000    300.000000             0.309190   709.000000
# 50%       6.000000    780.000000             0.809330   729.000000
# 75%      10.000000  11738.000000            12.227910   762.000000
# max      20.000000  63185.000000           714.909760   786.000000

# %%
result_constituencies_Candidate[result_constituencies_Candidate['mp_app_vote_percent']>100] # เลือกคอลัมน์มาดู
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 2593   NST_6   NST_6_1            5         5596            146.37719
# 2594   NST_6  NST_6_10            4         7731            202.22338
# 2601   NST_6   NST_6_4            6         5574            145.80173
# 2602   NST_6   NST_6_5            1        27331            714.90976
# 2605   NST_6   NST_6_8            3        10700            279.88491
# 2606   NST_6   NST_6_9            2        23260            608.42270
#
#       party_id
# 2593       705
# 2594       763
# 2601       701
# 2602       743
# 2605       726
# 2606       709

# %%
info_party_overview.isnull().any() #คอลัมน์ไหนในชีทเป็น Null
# Out:
# id          False
# party_no     True
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool

# %%
print(info_party_overview.shape)# หาจำนวนแถว คอลัมน์
# Out:
# (70, 6)

# %% [markdown]
# # วิธี fillna

# %%
 info_party_overview[ info_party_overview['party_no'].isnull()]
# Out:
#      id  party_no          name  abbr    color  \
# 9   711       NaN  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       NaN     พลังบูรพา   พบ.  #4696d6
# 17  720       NaN     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %%
fill_na_sasa = info_party_overview.fillna('99')

# %%
fill_na_sasa
# Out:
#      id party_no           name    abbr    color  \
# 0   701     26.0   ประชาธิปัตย์    ปชป.  #06aff3
# 1   702     63.0     ประชากรไทย    ปชท.  #0f41ce
# 2   703     60.0   ความหวังใหม่    ควม.  #e6b750
# 3   705     29.0       เพื่อไทย     พท.  #da3731
# 4   706     14.0  ชาติพัฒนากล้า    ชพก.  #233e8a
# ..  ...      ...            ...     ...      ...
# 65  780     55.0    ไทยก้าวหน้า    ทกน.  #b9bee3
# 66  781      9.0           พลัง      พ.  #8e8fc7
# 67  783     52.0  ชาติรุ่งเรือง    ชรร.  #9cb4c9
# 68  784     23.0       รวมใจไทย  ร.จ.ท.  #eec49a
# 69  786     20.0        เปลี่ยน      ป.  #cc898a
#
#                                              logo_url
# 0   https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1   https://cdn.ectreport.com/images/logos/ประชากร...
# 2   https://cdn.ectreport.com/images/logos/ความหวั...
# 3   https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4   https://cdn.ectreport.com/images/logos/ชาติพัฒ...
# ...

# %%
fill_na_sasa[fill_na_sasa['party_no']=='99'] # เปลี่ยนค่า null เป็น 99
# Out:
#      id party_no          name  abbr    color  \
# 9   711       99  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       99     พลังบูรพา   พบ.  #4696d6
# 17  720       99     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %% [markdown]
# #วิธีการ merge and join

# %%
cons_id1 = result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='ACR_1']
cons_id2 = result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='ACR_2']
cons_id3 = result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='AYA_1']

# %%
cons_id1
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %%
cons_id2
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 13   ACR_2   ACR_2_1            2        19188             17.16080       726
# 14   ACR_2  ACR_2_10            1        46881             41.92804       709
# 15   ACR_2  ACR_2_11           11          193              0.17261       742
# 16   ACR_2  ACR_2_12           12          173              0.15472       770
# 17   ACR_2   ACR_2_2            6         2027              1.81285       762
# 18   ACR_2   ACR_2_3            3        17637             15.77366       705
# 19   ACR_2   ACR_2_4           10          197              0.17619       712
# 20   ACR_2   ACR_2_5            5         2530              2.26271       701
# 21   ACR_2   ACR_2_6            8          519              0.46417       719
# 22   ACR_2   ACR_2_7            7         1156              1.03387       763
# 23   ACR_2   ACR_2_8            9          378              0.33806       769
# ...

# %%
TT_concat =  pd.concat([cons_id1, cons_id2]) #เอาข้อมูลมาต่อกัน

# %%
TT_concat
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %%
cons_id1.merge(Candidate_Constituency, on='mp_app_id', how='left')
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %% [markdown]
# # ตารางซ้าย.merge(ตารางขวา,left_on=' columnที่เป็น pk' , how='left' right_on = columnที่เป็น keyเชื่อม )

# %%
x1=cons_id1.merge(Candidate_Constituency , on='mp_app_id',how ='left')

# %%
x1
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %% [markdown]
# #วิธีการลบคำซ้ำ

# %%
x2=x1.merge(info_constituency, on='cons_id',how='left')

# %%
x2[['cons_id','mp_app_id','party_id','mp_app_name','mp_app_vote','mp_app_vote_percent']]
# Out:
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 2    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 3    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 4    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 5    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 6    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 7    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 8    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 9    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 11   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# ...

# %%
x3 = x2[['cons_id','mp_app_id','party_id','mp_app_name','mp_app_vote','mp_app_vote_percent']]

# %%
x3
# Out:
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 2    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 3    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 4    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 5    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 6    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 7    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 8    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 9    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 11   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# ...

# %%
# making a bool series
bool_series = x3.duplicated(subset = 'mp_app_name')
# passing NOT of bool series to see unique values only
x5 = x3[~bool_series]
# displaying data
x5
# Out:
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 2    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 4    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 6    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 8    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 12   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 14   ACR_1   ACR_1_4       719       นายอิทธิกร สุวะมาตย์          668
# 16   ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 18   ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 20   ACR_1   ACR_1_7       762           นายทวีชัย พลธานี         1281
# 22   ACR_1   ACR_1_8       705          นางสมหญิง บัวบุตร        21388
# ...

# %%
bool_series
# Out:
# 0     False
# 2     False
# 4     False
# 6     False
# 8     False
# 10    False
# 12    False
# 14    False
# 16    False
# 18    False
# 20    False
# 22    False
# 24    False
# dtype: bool

# %% [markdown]
# #วิธีการสร้าง dataframe และเพิ่ม column

# %%
y ={
      'LOL' : ['sc','sa','si','gh','jk','lg','fg','jg','kn','lj','fd','ng']
}

# %%
lol = pd.DataFrame(y) # lol = column
lol
# Out:
#    LOL
# 0   sc
# 1   sa
# 2   si
# 3   gh
# 4   jk
# 5   lg
# 6   fg
# 7   jg
# 8   kn
# 9   lj
# 10  fd
# 11  ng

# %%
xlol = x5.join(lol,how ='left')

# %% [markdown]
# #loop Ifelse groupby  max min mean count sum

# %%
TT_concat.groupby('cons_id')[['mp_app_vote','mp_app_id']].max().reset_index().sort_values(by = 'mp_app_vote',ascending = False)
# Out:
#   cons_id  mp_app_vote mp_app_id
# 1   ACR_2        46881   ACR_2_9
# 0   ACR_1        38275   ACR_1_9

# %%
k=
